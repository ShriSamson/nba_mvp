# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
import pandas as pd
import re

# %%
def url_to_soup(url):
    '''
    Takes in a URL string and returns a bs4 object
    '''
    html = urlopen(url)
    return BeautifulSoup(html, 'lxml')
    
def get_row_data(soup, start):
    '''
    Takes a bs4 object and a start index and returns a list of lists representing the table data
    '''    
    rows = soup.findAll('tr')[start:]
    rows_data = [
                [td.getText() for td in row.findAll('td')] 
                for row in rows
                ]
    
    return rows_data
    
def get_seasons(corpus):
    '''
    Takes a text corpus, returns a list of seasons found in the form yyyy-yy
    '''
    
    return re.findall(r'\d+-\d+', corpus)

def get_table_headers(soup, l, index):
    '''
    Takes in a soup object, limit, and index
    
    Args:
        soup (bs4 object): soup object 
        limit (int):
        years (int):
        
    Returns:
        headers : list of strings which represent column labels
    '''
    headers = [
               header.getText() 
               for header in soup.findAll('tr', limit=l)[index].findAll('th')
               ]
    return headers

# %%
url = 'https://www.basketball-reference.com/friv/mvp.html'

soup = url_to_soup(url)
headers = get_table_headers(soup, 2, 0)
rows_data = get_row_data(soup,1)

df_shortlist = pd.DataFrame(rows_data, columns = headers[1:])
df_shortlist
# Out:
#                   Player Team   W  L  W/L%   G  GS    MP    FG   FGA  ...  \
# 0          Stephen Curry  GSW  11  1  .917  12  12  33.8   9.2  20.3  ...
# 1           Nikola Jokić  DEN   8  4  .667  11  11  32.2   9.8  16.6  ...
# 2           Kevin Durant  BRK   9  4  .692  13  13  34.7  11.2  18.9  ...
# 3           Jimmy Butler  MIA   7  5  .583  11  11  33.0   8.0  15.2  ...
# 4       Montrezl Harrell  WAS   8  3  .727  11   2  29.6   6.5  10.1  ...
# 5             Chris Paul  PHO   8  3  .727  11  11  31.9   5.1  10.4  ...
# 6  Giannis Antetokounmpo  MIL   6  7  .462  12  12  32.9   9.5  19.2  ...
# 7            Rudy Gobert  UTA   8  4  .667  12  12  30.8   5.1   7.1  ...
# 8           James Harden  BRK   9  4  .692  13  13  34.2   6.0  14.0  ...
# 9         Draymond Green  GSW  11  1  .917  12  12  29.5   3.1   5.9  ...
#
#     DRB   TRB   AST  STL  BLK  TOV   PF   PTS    Prob%
# 0   5.5   6.3   6.4  1.6  0.7  3.3  1.5  28.4    41.4%
# 1  11.2  14.1   6.1  1.5  0.9  3.5  3.2  25.1    38.6%
# 2   7.9   8.4   5.2  0.5  0.6  3.4  1.2  29.4     7.9%
# 3   3.7   5.5   5.1  2.1  0.4  1.9  2.0  23.6     2.5%
# 4   6.8   9.3   1.9  0.6  1.2  1.4  2.4  18.1     2.4%
# 5   3.8   4.4  11.0  2.4  0.5  2.4  2.0  14.1     2.2%
# 6   9.9  11.8   6.0  1.1  1.8  3.0  3.0  26.6     1.5%
# 7  12.3  15.5   0.9  1.0  1.8  2.3  2.8  15.0     1.3%
# 8   6.7   7.8   9.0  1.1  0.8  4.8  2.4  19.8     1.2%
# 9   6.6   8.3   7.2  1.3  0.8  2.9  2.7   7.9     1.0%
#
# [10 rows x 32 columns]

# %%
features = ['Age','G','MP','PTS','TRB','AST','STL','BLK','FG%','3P%','FT%','WS','WS/48','W/L%','SRS']

# %%
headers
# Out:
# ['Rk',
#  'Player',
#  'Team',
#  'W',
#  'L',
#  'W/L%',
#  'G',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  '2P',
#  '2PA',
#  '2P%',
#  'eFG%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS',
#  '\xa0',
#  'Prob%']

# %%
set(features) - set(headers)
# Out:
# {'Age', 'SRS', 'WS', 'WS/48'}
